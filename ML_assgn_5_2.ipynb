# %%
# !kaggle datasets download -d sakshisatre/tips-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sakshisatre/tips-dataset
# License(s): apache-2.0
# Downloading tips-dataset.zip to /content
#   0% 0.00/1.83k [00:00<?, ?B/s]
# 100% 1.83k/1.83k [00:00<00:00, 2.56MB/s]

# %%
# !unzip -o /content/tips-dataset.zip
# Out:
# Archive:  /content/tips-dataset.zip
#   inflating: tip.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv('tip.csv')

print(df.describe())
df.head()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df = pd.get_dummies(df, columns=['sex', 'smoker', 'day', 'time'])

# %%
correlation_matrix = df.corr()

# %%
upper_triangle = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
print(upper_triangle)
# Out:
#              total_bill       tip      size  sex_Female  sex_Male  smoker_No  \
# total_bill          NaN  0.675734  0.598315   -0.144877  0.144877  -0.085721
# tip                 NaN       NaN  0.489299   -0.088862  0.088862  -0.005929
# size                NaN       NaN       NaN   -0.086195  0.086195   0.133178
# sex_Female          NaN       NaN       NaN         NaN -1.000000   0.002816
# sex_Male            NaN       NaN       NaN         NaN       NaN  -0.002816
# smoker_No           NaN       NaN       NaN         NaN       NaN        NaN
# smoker_Yes          NaN       NaN       NaN         NaN       NaN        NaN
# day_Fri             NaN       NaN       NaN         NaN       NaN        NaN
# day_Sat             NaN       NaN       NaN         NaN       NaN        NaN
# day_Sun             NaN       NaN       NaN         NaN       NaN        NaN
# day_Thur            NaN       NaN       NaN         NaN       NaN        NaN
# time_Dinner         NaN       NaN       NaN         NaN       NaN        NaN
# time_Lunch          NaN       NaN       NaN         NaN       NaN        NaN
#
#              smoker_Yes   day_Fri   day_Sat   day_Sun  day_Thur  time_Dinner  \
# total_bill     0.085721 -0.086168  0.054919  0.122953 -0.138174     0.183118
# tip            0.005929 -0.055463 -0.002790  0.125114 -0.095879     0.121629
# size          -0.133178 -0.142184 -0.041121  0.193054 -0.072598     0.103411
# sex_Female    -0.002816  0.071060 -0.053957 -0.168106  0.194445    -0.205231
# sex_Male       0.002816 -0.071060  0.053957  0.168106 -0.194445     0.205231
# smoker_No     -1.000000 -0.244316 -0.155744  0.181624  0.128534    -0.054921
# smoker_Yes          NaN  0.244316  0.155744 -0.181624 -0.128534     0.054921
# day_Fri             NaN       NaN -0.216319 -0.195451 -0.169608    -0.058159
# day_Sat             NaN       NaN       NaN -0.500682 -0.434480     0.462709
# day_Sun             NaN       NaN       NaN       NaN -0.392566     0.418071
# day_Thur            NaN       NaN       NaN       NaN       NaN    -0.917996
# time_Dinner         NaN       NaN       NaN       NaN       NaN          NaN
# time_Lunch          NaN       NaN       NaN       NaN       NaN          NaN
#
#              time_Lunch
# total_bill    -0.183118
# tip           -0.121629
# size          -0.103411
# sex_Female     0.205231
# sex_Male      -0.205231
# smoker_No      0.054921
# smoker_Yes    -0.054921
# day_Fri        0.058159
# day_Sat       -0.462709
# day_Sun       -0.418071
# day_Thur       0.917996
# time_Dinner   -1.000000
# time_Lunch          NaN

# %%
plt.figure(figsize=(12, 9))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

plt.title('Correlation Matrix')
plt.show()
